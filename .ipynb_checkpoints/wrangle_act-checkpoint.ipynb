# %% [markdown]
# # Project: Wrangling and Analyze Data

# %% [markdown]
# ## Data Gathering
# In the cell below, gather **all** three pieces of data for this project and load them in the notebook. **Note:** the methods required to gather each data are different.
# 1. Directly download the WeRateDogs Twitter archive data (twitter_archive_enhanced.csv)

# %%
#importing packages 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import json
import os
# %matplotlib inline

from bs4 import BeautifulSoup as bs

# %%
#reading the archive file
archive = pd.read_csv('twitter-archive-enhanced.csv')
archive
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %% [markdown]
# 2. Use the Requests library to download the tweet image prediction (image_predictions.tsv)

# %%
#using the response library to get the image predictions
url = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)

# %%
response.content
# Out:
# b"tweet_id\tjpg_url\timg_num\tp1\tp1_conf\tp1_dog\tp2\tp2_conf\tp2_dog\tp3\tp3_conf\tp3_dog\n666020888022790149\thttps://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg\t1\tWelsh_springer_spaniel\t0.465074\tTrue\tcollie\t0.156665\tTrue\tShetland_sheepdog\t0.0614285\tTrue\n666029285002620928\thttps://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg\t1\tredbone\t0.506826\tTrue\tminiature_pinscher\t0.07419169999999999\tTrue\tRhodesian_ridgeback\t0.07201\tTrue\n666033412701032449\thttps://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg\t1\tGerman_shepherd\t0.596461\tTrue\tmalinois\t0.13858399999999998\tTrue\tbloodhound\t0.11619700000000001\tTrue\n666044226329800704\thttps://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg\t1\tRhodesian_ridgeback\t0.408143\tTrue\tredbone\t0.360687\tTrue\tminiature_pinscher\t0.222752\tTrue\n666049248165822465\thttps://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg\t1\tminiature_pinscher\t0.560311\tTrue\tRottweiler\t0.243682\tTrue\tDoberman\t0.154629\tTrue\n666050758794694657\thttps://pbs.twimg.co
# ...

# %%
#checking in which working directory we in
print(os.getcwd())
# Out:
# /home/workspace

# %%
#lisiting the files and folders in our working directory
print(os.listdir())
# Out:
# ['twitter-archive-enhanced.csv', 'twitter-api.py', 'twitter_archive_master.csv', 'act_report.ipynb', 'tweet_json.txt', 'wrangle_report.pdf', 'act_report.pdf', 'tweet-json.txt', '.ipynb_checkpoints', 'wrangle_report.ipynb', 'image_predictions.tsv', 'wrangle_act.ipynb']

# %%
workspace = os.getcwd()

# %%
#writing the tsv predictions file to thw working directory
with open(os.path.join(workspace, 'image_predictions.tsv'), mode='wb') as file:
    file.write(response.content)

# %%
print(os.listdir())
# Out:
# ['twitter-archive-enhanced.csv', 'twitter-api.py', 'twitter_archive_master.csv', 'act_report.ipynb', 'tweet_json.txt', 'wrangle_report.pdf', 'act_report.pdf', 'tweet-json.txt', '.ipynb_checkpoints', 'wrangle_report.ipynb', 'image_predictions.tsv', 'wrangle_act.ipynb']

# %%
#reading the tsv file
prdctns = pd.read_csv('image_predictions.tsv', sep='\t')
prdctns
# Out:
#                 tweet_id                                            jpg_url  \
# 0     666020888022790149    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1     666029285002620928    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2     666033412701032449    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3     666044226329800704    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4     666049248165822465    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 5     666050758794694657    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 7     666055525042405380    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 8     666057090499244032    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 9     666058600524156928    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 10    666063827256086533    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# ...

# %% [markdown]
# 3. Use the Tweepy library to query additional data via the Twitter API (tweet_json.txt)

# %% [markdown]
# #### The tweet api keys were expired so just imported the tweet-json.txt instead

# %% [markdown]
# import tweepy
# from tweepy import OAuthHandler
# import json
# from timeit import default_timer as timer
#
# # Query Twitter API for each tweet in the Twitter archive and save JSON in a text file
# # These are hidden to comply with Twitter's API terms and conditions
# consumer_key = 'HIDDEN'
# consumer_secret = 'HIDDEN'
# access_token = 'HIDDEN'
# access_secret = 'HIDDEN'
#
# auth = OAuthHandler(consumer_key, consumer_secret)
# auth.set_access_token(access_token, access_secret)
#
# api = tweepy.API(auth, wait_on_rate_limit=True)
#
# # NOTE TO STUDENT WITH MOBILE VERIFICATION ISSUES:
# # df_1 is a DataFrame with the twitter_archive_enhanced.csv file. You may have to
# # change line 17 to match the name of your DataFrame with twitter_archive_enhanced.csv
# # NOTE TO REVIEWER: this student had mobile verification issues so the following
# # Twitter API code was sent to this student from a Udacity instructor
# # Tweet IDs for which to gather additional data via Twitter's API
# tweet_ids = archive.tweet_id.values
# len(tweet_ids)
#
# # Query Twitter's API for JSON data for each tweet ID in the Twitter archive
# count = 0
# fails_dict = {}
# start = timer()
# # Save each tweet's returned JSON as a new line in a .txt file
# with open('tweet_json.txt', 'w') as outfile:
#     # This loop will likely take 20-30 minutes to run because of Twitter's rate limit
#     for tweet_id in tweet_ids:
#         count += 1
#         print(str(count) + ": " + str(tweet_id))
#         try:
#             tweet = api.get_status(tweet_id, tweet_mode='extended')
#             print("Success")
#             json.dump(tweet._json, outfile)
#             outfile.write('\n')
#         except tweepy.TweepError as e:
#             print("Fail")
#             fails_dict[tweet_id] = e
#             pass
# end = timer()
# print(end - start)
# print(fails_dict)

# %% [markdown]
# ### Reading the json using json

# %%
#creating an empty set to populate with data
df_list = []

with open('tweet-json.txt', 'r') as file:
    for line in file:
        column = json.loads(line)
        tweet_id = column["id"]
        retweet_count = column["retweet_count"]
        favorite_count = column["favorite_count"]
         
        # Append to list of dictionaries
        df_list.append({'tweet_id': tweet_id,
                        'retweet count': retweet_count,
                         'favorite count': favorite_count
                          })
        
twt_api = pd.DataFrame(df_list, columns = ['tweet_id', 'retweet count', 'favorite count'])

# %%
#checking if ot worked
twt_api
# Out:
#                 tweet_id  retweet count  favorite count
# 0     892420643555336193           8853           39467
# 1     892177421306343426           6514           33819
# 2     891815181378084864           4328           25461
# 3     891689557279858688           8964           42908
# 4     891327558926688256           9774           41048
# 5     891087950875897856           3261           20562
# 6     890971913173991426           2158           12041
# 7     890729181411237888          16716           56848
# 8     890609185150312448           4429           28226
# 9     890240255349198849           7711           32467
# 10    890006608113172480           7624           31166
# 11    889880896479866881           5156           28268
# 12    889665388333682689           8538           38818
# 13    889638837579907072           4735           27672
# 14    889531135344209921           2321           15359
# 15    889278841981685760           5637           25652
# ...

# %% [markdown]
# ## Assessing Data
# In this section, detect and document at least **eight (8) quality issues and two (2) tidiness issue**. You must use **both** visual assessment
# programmatic assessement to assess the data.
#
# **Note:** pay attention to the following key points when you access the data.
#
# * You only want original ratings (no retweets) that have images. Though there are 5000+ tweets in the dataset, not all are dog ratings and some are retweets.
# * Assessing and cleaning the entire dataset completely would require a lot of time, and is not necessary to practice and demonstrate your skills in data wrangling. Therefore, the requirements of this project are only to assess and clean at least 8 quality issues and at least 2 tidiness issues in this dataset.
# * The fact that the rating numerators are greater than the denominators does not need to be cleaned. This [unique rating system](http://knowyourmeme.com/memes/theyre-good-dogs-brent) is a big part of the popularity of WeRateDogs.
# * You do not need to gather the tweets beyond August 1st, 2017. You can, but note that you won't be able to gather the image predictions for these tweets since you don't have access to the algorithm used.

# %% [markdown]
# ### Visual and Programatic Assessments

# %%
pd.set_option('display.max_colwidth', -1)

# %%
archive
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193 NaN                    NaN
# 1     892177421306343426 NaN                    NaN
# 2     891815181378084864 NaN                    NaN
# 3     891689557279858688 NaN                    NaN
# 4     891327558926688256 NaN                    NaN
# 5     891087950875897856 NaN                    NaN
# 6     890971913173991426 NaN                    NaN
# 7     890729181411237888 NaN                    NaN
# 8     890609185150312448 NaN                    NaN
# 9     890240255349198849 NaN                    NaN
# 10    890006608113172480 NaN                    NaN
# 11    889880896479866881 NaN                    NaN
# 12    889665388333682689 NaN                    NaN
# 13    889638837579907072 NaN                    NaN
# 14    889531135344209921 NaN                    NaN
# 15    889278841981685760 NaN                    NaN
# 16    888917238123831296 NaN                    NaN
# ...

# %%
archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
prdctns
# Out:
#                 tweet_id  \
# 0     666020888022790149
# 1     666029285002620928
# 2     666033412701032449
# 3     666044226329800704
# 4     666049248165822465
# 5     666050758794694657
# 6     666051853826850816
# 7     666055525042405380
# 8     666057090499244032
# 9     666058600524156928
# 10    666063827256086533
# 11    666071193221509120
# 12    666073100786774016
# 13    666082916733198337
# 14    666094000022159362
# 15    666099513787052032
# 16    666102155909144576
# 17    666104133288665088
# 18    666268910803644416
# 19    666273097616637952
# 20    666287406224695296
# 21    666293911632134144
# 22    666337882303524864
# 23    666345417576210432
# 24    666353288456101888
# 25    666362758909284353
# 26    666373753744588802
# 27    666396247373291520
# 28    666407126856765440
# 29    666411507551481857
# ...                  ...
# 2045  886366144734445568
# 2046  886680336477933568
# 2047  886736880519319552
# 2048  886983233522544640
# ...

# %%
prdctns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
twt_api
# Out:
#                 tweet_id  retweet count  favorite count
# 0     892420643555336193  8853           39467
# 1     892177421306343426  6514           33819
# 2     891815181378084864  4328           25461
# 3     891689557279858688  8964           42908
# 4     891327558926688256  9774           41048
# 5     891087950875897856  3261           20562
# 6     890971913173991426  2158           12041
# 7     890729181411237888  16716          56848
# 8     890609185150312448  4429           28226
# 9     890240255349198849  7711           32467
# 10    890006608113172480  7624           31166
# 11    889880896479866881  5156           28268
# 12    889665388333682689  8538           38818
# 13    889638837579907072  4735           27672
# 14    889531135344209921  2321           15359
# 15    889278841981685760  5637           25652
# 16    888917238123831296  4709           29611
# 17    888804989199671297  4559           26080
# 18    888554962724278272  3732           20290
# ...

# %%
twt_api.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id          2354 non-null int64
# retweet count     2354 non-null int64
# favorite count    2354 non-null int64
# dtypes: int64(3)
# memory usage: 55.2 KB

# %%
twt_api['tweet_id'].nunique()
# Out:
# 2354

# %% [markdown]
# ### Quality issues
#
# 1. Cannot use tweets beyond 2017 as we  don't have access to the algorithm used.
#
# 2. Should not be using any retweets and must use only original tweets.
#
# 3. Fix incorrectly extracted rating values.
#
# 4. Errornous datatypes (timestamp,tweet_id,rating_numerator ).
#
# 5. From the twitter archive dataset there is missing dog names,incomplete dog names and invalid dog names.
#
# 6. Column headers should be more descriptive.
#
# 7. From the predictions dataset some of the most confident predictions are not dogs meaning some of the images are not dog  images
#
# 8. Dog breeds should standardized

# %% [markdown]
# ### Tidiness issues
# 1. All data sets are related so they should all be in one data frame.
# 2. The observations duggo, puppo, flooter and puppo should be under one column.

# %% [markdown]
# ## Cleaning Data
# In this section, clean **all** of the issues you documented while assessing.
#
# **Note:** Make a copy of the original data before cleaning. Cleaning includes merging individual pieces of data according to the rules of [tidy data](https://cran.r-project.org/web/packages/tidyr/vignettes/tidy-data.html). The result should be a high-quality and tidy master pandas DataFrame (or DataFrames, if appropriate).

# %%
# Make copies of original pieces of data
archive_cp = archive.copy()
prdctns_cp = prdctns.copy()
api_cp = twt_api.copy()

# %%
archive_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
api_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id          2354 non-null int64
# retweet count     2354 non-null int64
# favorite count    2354 non-null int64
# dtypes: int64(3)
# memory usage: 55.2 KB

# %% [markdown]
# ### Issue #1:
#
# ### removing retweets

# %% [markdown]
# #### Define:
# Remove retweets and only be left with original tweets

# %% [markdown]
# ### code

# %%
archive_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
archive_cp
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193 NaN                    NaN
# 1     892177421306343426 NaN                    NaN
# 2     891815181378084864 NaN                    NaN
# 3     891689557279858688 NaN                    NaN
# 4     891327558926688256 NaN                    NaN
# 5     891087950875897856 NaN                    NaN
# 6     890971913173991426 NaN                    NaN
# 7     890729181411237888 NaN                    NaN
# 8     890609185150312448 NaN                    NaN
# 9     890240255349198849 NaN                    NaN
# 10    890006608113172480 NaN                    NaN
# 11    889880896479866881 NaN                    NaN
# 12    889665388333682689 NaN                    NaN
# 13    889638837579907072 NaN                    NaN
# 14    889531135344209921 NaN                    NaN
# 15    889278841981685760 NaN                    NaN
# 16    888917238123831296 NaN                    NaN
# ...

# %%
#checking how many non null values present in retweeted_status_id
archive_cp["retweeted_status_id"].notnull().sum()
# Out:
# 181

# %%
#only extracting null rows from retweeted_status_id
archive_cp = archive_cp.loc[archive_cp["retweeted_status_id"].isnull()]

# %%
#checking how many non null values present in in_reply_to_status_id

archive_cp["in_reply_to_status_id"].notnull().sum()
# Out:
# 78

# %%
#only extracting null rows from in_reply_to_status_id
archive_cp = archive_cp.loc[archive_cp["in_reply_to_status_id"].isnull()]

# %% [markdown]
# ### Test

# %%
archive_cp["retweeted_status_id"].notnull().sum()
# Out:
# 0

# %%
archive_cp["in_reply_to_status_id"].notnull().sum()
# Out:
# 0

# %%
archive_cp["in_reply_to_user_id"].notnull().sum()
# Out:
# 0

# %%
archive_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2097 non-null int64
# in_reply_to_status_id         0 non-null float64
# in_reply_to_user_id           0 non-null float64
# timestamp                     2097 non-null object
# source                        2097 non-null object
# text                          2097 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 2094 non-null object
# rating_numerator              2097 non-null int64
# rating_denominator            2097 non-null int64
# name                          2097 non-null object
# doggo                         2097 non-null object
# floofer                       2097 non-null object
# pupper                        2097 non-null object
# puppo                         2097 non-null object
# ...

# %% [markdown]
# #### Issue #1.2:
#
# #### Define
# > Drop from the twitter archive dataset the columns: in_reply_to_status_id and in_reply_to_user_id, retweeted_status_id, retweeted_status_user_id and retweeted_status_timestamp columns

# %% [markdown]
# #### Code

# %%
#droping the columns from the data frame
archive_cp.drop(["in_reply_to_status_id", "in_reply_to_user_id", "retweeted_status_id","retweeted_status_user_id","retweeted_status_timestamp"], axis = 1, inplace = True)

# %% [markdown]
# #### Test

# %%
archive_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2097 non-null int64
# timestamp             2097 non-null object
# source                2097 non-null object
# text                  2097 non-null object
# expanded_urls         2094 non-null object
# rating_numerator      2097 non-null int64
# rating_denominator    2097 non-null int64
# name                  2097 non-null object
# doggo                 2097 non-null object
# floofer               2097 non-null object
# pupper                2097 non-null object
# puppo                 2097 non-null object
# dtypes: int64(3), object(9)
# memory usage: 213.0+ KB

# %% [markdown]
# ### Issue #2:

# %% [markdown]
# ### Define
# > Fiixing incorrectly Extracted ratings with decimals.

# %% [markdown]
# ### Code

# %%
#extracring all the ratings from the text
ratings = pd.DataFrame(archive_cp.text.str.extract('((?:\d+\.)?\d+)\/(\d+)', expand=True), )
ratings
# Out:
#        0   1
# 0     13  10
# 1     13  10
# 2     12  10
# 3     13  10
# 4     12  10
# 5     13  10
# 6     13  10
# 7     13  10
# 8     13  10
# 9     14  10
# 10    13  10
# 11    13  10
# 12    13  10
# 13    12  10
# 14    13  10
# 15    13  10
# 16    12  10
# 17    13  10
# 18    13  10
# 20    12  10
# 21    13  10
# 22    14  10
# 23    13  10
# 24    13  10
# 25    12  10
# 26    13  10
# 27    13  10
# 28    13  10
# 29    12  10
# 31    13  10
# ...   ..  ..
# 2326  2   10
# 2327  7   10
# 2328  9   10
# 2329  11  10
# 2330  6   10
# 2331  8   10
# 2332  10  10
# 2333  9   10
# 2334  3   10
# 2335  1   2
# 2336  11  10
# 2337  10  10
# 2338  1   10
# 2339  11  10
# 2340  8   10
# 2341  9   10
# 2342  6   10
# 2343  10  10
# 2344  9   10
# 2345  10  10
# 2346  8   10
# 2347  9   10
# 2348  10  10
# 2349  2   10
# 2350  10  10
# 2351  5   10
# 2352  6   10
# 2353  9   10
# 2354  7   10
# 2355  8   10
#
# [2097 rows x 2 columns]

# %%
ratings[0]
# Out:
# 0       13
# 1       13
# 2       12
# 3       13
# 4       12
# 5       13
# 6       13
# 7       13
# 8       13
# 9       14
# 10      13
# 11      13
# 12      13
# 13      12
# 14      13
# 15      13
# 16      12
# 17      13
# 18      13
# 20      12
# 21      13
# 22      14
# 23      13
# 24      13
# 25      12
# 26      13
# 27      13
# 28      13
# 29      12
# 31      13
#         ..
# 2326    2
# 2327    7
# 2328    9
# 2329    11
# 2330    6
# 2331    8
# 2332    10
# 2333    9
# 2334    3
# 2335    1
# 2336    11
# 2337    10
# 2338    1
# 2339    11
# 2340    8
# 2341    9
# 2342    6
# 2343    10
# 2344    9
# 2345    10
# 2346    8
# 2347    9
# 2348    10
# 2349    2
# 2350    10
# 2351    5
# 2352    6
# 2353    9
# 2354    7
# 2355    8
# Name: 0, Length: 2097, dtype: object

# %%
#extracting only the numerators 
archive_cp.rating_numerator = ratings[0]

# %%
#extracting only the denominators 
archive_cp.rating_denominator = ratings[1]

# %% [markdown]
# ### Test

# %%
archive_cp.rating_numerator
# Out:
# 0       13
# 1       13
# 2       12
# 3       13
# 4       12
# 5       13
# 6       13
# 7       13
# 8       13
# 9       14
# 10      13
# 11      13
# 12      13
# 13      12
# 14      13
# 15      13
# 16      12
# 17      13
# 18      13
# 20      12
# 21      13
# 22      14
# 23      13
# 24      13
# 25      12
# 26      13
# 27      13
# 28      13
# 29      12
# 31      13
#         ..
# 2326    2
# 2327    7
# 2328    9
# 2329    11
# 2330    6
# 2331    8
# 2332    10
# 2333    9
# 2334    3
# 2335    1
# 2336    11
# 2337    10
# 2338    1
# 2339    11
# 2340    8
# 2341    9
# 2342    6
# 2343    10
# 2344    9
# 2345    10
# 2346    8
# 2347    9
# 2348    10
# 2349    2
# 2350    10
# 2351    5
# 2352    6
# 2353    9
# 2354    7
# 2355    8
# Name: rating_numerator, Length: 2097, dtype: object

# %%
archive_cp.rating_denominator
# Out:
# 0       10
# 1       10
# 2       10
# 3       10
# 4       10
# 5       10
# 6       10
# 7       10
# 8       10
# 9       10
# 10      10
# 11      10
# 12      10
# 13      10
# 14      10
# 15      10
# 16      10
# 17      10
# 18      10
# 20      10
# 21      10
# 22      10
# 23      10
# 24      10
# 25      10
# 26      10
# 27      10
# 28      10
# 29      10
# 31      10
#         ..
# 2326    10
# 2327    10
# 2328    10
# 2329    10
# 2330    10
# 2331    10
# 2332    10
# 2333    10
# 2334    10
# 2335    2
# 2336    10
# 2337    10
# 2338    10
# 2339    10
# 2340    10
# 2341    10
# 2342    10
# 2343    10
# 2344    10
# 2345    10
# 2346    10
# 2347    10
# 2348    10
# 2349    10
# 2350    10
# 2351    10
# 2352    10
# 2353    10
# 2354    10
# 2355    10
# Name: rating_denominator, Length: 2097, dtype: object

# %% [markdown]
# ### Issue #3:

# %% [markdown]
# #### Define:
# > Change the timestamp datatype from object to datetime
#
# > change text datatype to string
#
# > rating numerator to float

# %% [markdown]
# #### Code

# %%
from datetime import date

# %%
#changing the timestamp data type to date time
archive_cp.timestamp = pd.to_datetime(archive_cp.timestamp)

# %%
archive_cp = archive_cp.infer_objects()

# %%
#change text datatype to string
archive_cp.text = archive_cp.text.astype(str)

# %%
# rating numerator to float
archive_cp.rating_numerator = archive.rating_numerator.astype(float)

# %% [markdown]
# #### Test

# %%
archive_cp.text.dtypes
# Out:
# dtype('O')

# %%
archive_cp.info()
#it was changed succefully
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2355
# Data columns (total 12 columns):
# tweet_id              2097 non-null int64
# timestamp             2097 non-null datetime64[ns]
# source                2097 non-null object
# text                  2097 non-null object
# expanded_urls         2094 non-null object
# rating_numerator      2097 non-null float64
# rating_denominator    2097 non-null object
# name                  2097 non-null object
# doggo                 2097 non-null object
# floofer               2097 non-null object
# pupper                2097 non-null object
# puppo                 2097 non-null object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(9)
# memory usage: 213.0+ KB

# %% [markdown]
# ### Issue #4:Tidiness

# %% [markdown]
# #### Define
# > Combine the dog catergories into one column
#
# > Drop the doggo, floofer, pupper, puppo columns
#
# > Replace the 'None' with Nan in the new column

# %% [markdown]
# #### Code

# %%
archive_cp["doggo"].value_counts()
# Out:
# None     2014
# doggo    83
# Name: doggo, dtype: int64

# %%
archive_cp["floofer"].value_counts()
# Out:
# None       2087
# floofer    10
# Name: floofer, dtype: int64

# %%
archive_cp["pupper"].value_counts()
# Out:
# None      1867
# pupper    230
# Name: pupper, dtype: int64

# %%
archive_cp["puppo"].value_counts()
# Out:
# None     2073
# puppo    24
# Name: puppo, dtype: int64

# %%
#  replacing None in stage columns with empty string.
archive_cp.doggo.replace('None', '', inplace=True)  
archive_cp.floofer.replace('None', '', inplace=True)  
archive_cp.pupper.replace('None', '', inplace=True)  
archive_cp.puppo.replace('None', '', inplace=True)

# %%
# Combining stage columns.
archive_cp['stage'] = archive_cp.doggo + archive_cp.floofer + archive_cp.pupper + archive_cp.puppo

# %%
# Then format entries with multiple dog stages which appeared like doggopupper.

archive_cp.loc[archive_cp.stage == 'doggopupper', 'stage'] = 'doggo,pupper' 
archive_cp.loc[archive_cp.stage == 'doggopuppo', 'stage'] = 'doggo,puppo' 
archive_cp.loc[archive_cp.stage == 'doggofloofer', 'stage'] = 'doggo,floofer'

# %%
#we can then drop the individual doggo,floofer,pupper and puppo columns
archive_cp.drop(["doggo", "floofer", "pupper","puppo"], axis = 1, inplace = True)

# %%
# rplace all the empty spaces with Nan
archive_cp.stage.replace('', np.nan,inplace=True)

# %% [markdown]
# #### Test

# %%
archive_cp
# Out:
#                 tweet_id           timestamp  \
# 0     892420643555336193 2017-08-01 16:23:56
# 1     892177421306343426 2017-08-01 00:17:27
# 2     891815181378084864 2017-07-31 00:18:03
# 3     891689557279858688 2017-07-30 15:58:51
# 4     891327558926688256 2017-07-29 16:00:24
# 5     891087950875897856 2017-07-29 00:08:17
# 6     890971913173991426 2017-07-28 16:27:12
# 7     890729181411237888 2017-07-28 00:22:40
# 8     890609185150312448 2017-07-27 16:25:51
# 9     890240255349198849 2017-07-26 15:59:51
# 10    890006608113172480 2017-07-26 00:31:25
# 11    889880896479866881 2017-07-25 16:11:53
# 12    889665388333682689 2017-07-25 01:55:32
# 13    889638837579907072 2017-07-25 00:10:02
# 14    889531135344209921 2017-07-24 17:02:04
# 15    889278841981685760 2017-07-24 00:19:32
# 16    888917238123831296 2017-07-23 00:22:39
# 17    888804989199671297 2017-07-22 16:56:37
# 18    888554962724278272 2017-07-22 00:23:06
# 20    888078434458587136 2017-07-20 16:49:33
# ...

# %%
archive_cp['stage'].value_counts()
#columns were dropped
# Out:
# pupper           221
# doggo            72
# puppo            23
# floofer          9
# doggo,pupper     9
# doggo,floofer    1
# doggo,puppo      1
# Name: stage, dtype: int64

# %% [markdown]
# ### Issue #5:

# %% [markdown]
# ### Define
#
# > Changing incomplete dog names and invalid dog names

# %% [markdown]
# ### Code

# %%
#visualising lower case names
mask = archive_cp.name.str.contains('^[a-z]', regex = True)
archive_cp[mask].name.value_counts().sort_index()
# Out:
# a               55
# actually        2
# all             1
# an              6
# by              1
# getting         2
# his             1
# incredibly      1
# infuriating     1
# just            3
# life            1
# light           1
# mad             1
# my              1
# not             2
# officially      1
# old             1
# one             4
# quite           3
# space           1
# such            1
# the             8
# this            1
# unacceptable    1
# very            4
# Name: name, dtype: int64

# %%
#replacing lower case and invalid names names with Nan
archive_cp.name.replace('^[a-z]', np.nan,inplace=True, regex = True)

# %% [markdown]
# ### Test

# %%
archive_cp[mask].name.value_counts().sort_index()
# Out:
# Series([], Name: name, dtype: int64)

# %% [markdown]
# > Replacing  missing dog names and None with Nan

# %%
#changing None to Nan
archive_cp.name.replace(['','None'], np.nan,inplace=True)

# %%
#Capitalising the 1st Letter
archive_cp['name'] = archive_cp['name'].str.capitalize()

# %% [markdown]
# ### Test

# %%
archive_cp['name'].value_counts().sort_index()
# Out:
# Abby            2
# Ace             1
# Acro            1
# Adele           1
# Aiden           1
# Aja             1
# Akumi           1
# Al              1
# Albert          2
# Albus           2
# Aldrick         1
# Alejandro       1
# Alexander       1
# Alexanderson    1
# Alf             1
# Alfie           4
# Alfy            1
# Alice           2
# Amber           1
# Ambrose         1
# Amy             1
# Amélie          1
# Anakin          1
# Andru           1
# Andy            1
# Angel           1
# Anna            1
# Anthony         1
# Antony          1
# Apollo          1
#                ..
# Walker          1
# Wallace         3
# Wally           2
# Walter          3
# Watson          2
# Wesley          1
# Wiggles         1
# Willem          1
# William         1
# Willie          1
# Willow          1
# Willy           1
# Wilson          3
# Winifred        1
# Winnie          4
# Winston         8
# Wishes          1
# Wyatt           3
# Yoda            1
# ...

# %% [markdown]
# ### Issue #6:

# %% [markdown]
# #### Define
# > Column headers should be more descriptive.

# %% [markdown]
# ### Code

# %%
#changing the column jpg_url to image_url
prdctns_cp.rename(columns={"jpg_url":"image_url"}, inplace=True)

# %% [markdown]
# ### Test

# %%
prdctns_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id     2075 non-null int64
# image_url    2075 non-null object
# img_num      2075 non-null int64
# p1           2075 non-null object
# p1_conf      2075 non-null float64
# p1_dog       2075 non-null bool
# p2           2075 non-null object
# p2_conf      2075 non-null float64
# p2_dog       2075 non-null bool
# p3           2075 non-null object
# p3_conf      2075 non-null float64
# p3_dog       2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %% [markdown]
# ### Issue #7:

# %% [markdown]
# #### Define
# Gather only the predictions that are dogs and drop the rest

# %% [markdown]
# #### Code

# %% [markdown]
# ### First getting true predictions from the highest level column

# %%
#first getting true predictions from the highest level column 
prdctns_cp_true1 = prdctns_cp.query('p1_dog == True')

# %%
#droping the other columns
prdctns_cp_true1.drop(["img_num","p1_dog","p1_conf",'p2',"p2_conf","p2_dog","p3","p3_conf","p3_dog"], axis = 1, inplace = True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
#renaming the predictions column to breed
prdctns_cp_true1.rename(columns={"p1":"breed"}, inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %% [markdown]
# ### Secondly getting the predictions that were true but might have been missed with the 1st prediction or mislabled

# %%
#secondly getting the prdictions that were true but might have been missed with the 1st prediction or mislabled
prdctns_cp_true2 = prdctns_cp.loc[(prdctns_cp['p2_dog'] == True) &  (prdctns_cp['p1_dog'] == False)]

# %%
#droping the other columns
prdctns_cp_true2.drop(["img_num","p2_dog","p2_conf",'p1',"p1_conf","p1_dog","p3","p3_conf","p3_dog"], axis = 1, inplace = True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:3697: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
#renaming the predictions column to breed
prdctns_cp_true2.rename(columns={"p2":"breed"}, inplace=True)
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py:3781: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %% [markdown]
# ### Finally getting the true predictiction from the least confident column, that were false in the other columns  two previous columns

# %%
#isolating the true predictions
prdctns_cp_true3 = prdctns_cp.loc[(prdctns_cp['p3_dog'] == True)]

# %%
#getting true predictions that were false in the other columns
prdctns_cp_true3 = prdctns_cp_true3.loc[(prdctns_cp_true3['p1_dog'] == False) & (prdctns_cp_true3['p2_dog'] == False)]

# %%
#droping the other columns
prdctns_cp_true3.drop(["img_num","p3_dog","p3_conf",'p2',"p2_conf","p2_dog","p1","p1_conf","p1_dog"], axis = 1, inplace = True)

# %%
#renaming the predictions column to breed
prdctns_cp_true3.rename(columns={"p3":"breed"}, inplace=True)

# %% [markdown]
# #### Test

# %%
prdctns_cp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id     2075 non-null int64
# image_url    2075 non-null object
# img_num      2075 non-null int64
# p1           2075 non-null object
# p1_conf      2075 non-null float64
# p1_dog       2075 non-null bool
# p2           2075 non-null object
# p2_conf      2075 non-null float64
# p2_dog       2075 non-null bool
# p3           2075 non-null object
# p3_conf      2075 non-null float64
# p3_dog       2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
prdctns_cp_true1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1532 entries, 0 to 2073
# Data columns (total 3 columns):
# tweet_id     1532 non-null int64
# image_url    1532 non-null object
# breed        1532 non-null object
# dtypes: int64(1), object(2)
# memory usage: 47.9+ KB

# %%
prdctns_cp_true2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 22 to 2071
# Data columns (total 3 columns):
# tweet_id     155 non-null int64
# image_url    155 non-null object
# breed        155 non-null object
# dtypes: int64(1), object(2)
# memory usage: 4.8+ KB

# %%
prdctns_cp_true3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 8 to 2026
# Data columns (total 3 columns):
# tweet_id     64 non-null int64
# image_url    64 non-null object
# breed        64 non-null object
# dtypes: int64(1), object(2)
# memory usage: 2.0+ KB

# %% [markdown]
# ### Issue #8: Tidiness

# %% [markdown]
# #### Define
# Merge the predictions to one column named breed as this one variable

# %% [markdown]
# #### Code

# %% [markdown]
# #### Merging all the the predictions columns together

# %%
#merging the predictions columns
prdctns_dogs = pd.concat([prdctns_cp_true1,prdctns_cp_true2,prdctns_cp_true3],ignore_index=True)

# %%
# standardizing dog breeds
#Capitalising the 1st Letter
prdctns_dogs['breed'] = prdctns_dogs['breed'].str.capitalize()

# %% [markdown]
# ### Test

# %%
prdctns_dogs
# Out:
#                 tweet_id  \
# 0     666020888022790149
# 1     666029285002620928
# 2     666033412701032449
# 3     666044226329800704
# 4     666049248165822465
# 5     666050758794694657
# 6     666055525042405380
# 7     666058600524156928
# 8     666063827256086533
# 9     666071193221509120
# 10    666073100786774016
# 11    666082916733198337
# 12    666094000022159362
# 13    666099513787052032
# 14    666102155909144576
# 15    666273097616637952
# 16    666287406224695296
# 17    666345417576210432
# 18    666353288456101888
# 19    666373753744588802
# 20    666396247373291520
# 21    666407126856765440
# 22    666418789513326592
# 23    666421158376562688
# 24    666428276349472768
# 25    666435652385423360
# 26    666437273139982337
# 27    666447344410484738
# 28    666454714377183233
# 29    666644823164719104
# ...                  ...
# 1721  710153181850935296
# 1722  711306686208872448
# 1723  723179728551723008
# 1724  727286334147182592
# ...

# %%
#checking if any rows were duplicated during the process
sum(prdctns_dogs['tweet_id'].duplicated())
# Out:
# 0

# %%
prdctns_dogs['tweet_id'].nunique()
# Out:
# 1751

# %%
prdctns_dogs[prdctns_dogs.tweet_id == 891689557279858688]
# Out:
#                 tweet_id                                        image_url  \
# 1686  891689557279858688  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
#
#                    breed
# 1686  Labrador_retriever

# %%
prdctns_dogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1751 entries, 0 to 1750
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweet_id   1751 non-null   int64
#  1   image_url  1751 non-null   object
#  2   breed      1751 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 41.2+ KB

# %% [markdown]
# ### Merging all the the datasets together

# %%
#merging the archive dataframe copy and tweeter api dataframe
merged_1 = pd.merge(archive_cp,api_cp)

# %%
#merging the all data frames into one
weRatedogs_clean = pd.merge(merged_1,prdctns_dogs)

# %% [markdown]
# #### Test

# %%
merged_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2097 entries, 0 to 2096
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            2097 non-null   int64
#  1   timestamp           2097 non-null   datetime64[ns, UTC]
#  2   source              2097 non-null   object
#  3   text                2097 non-null   object
#  4   expanded_urls       2094 non-null   object
#  5   rating_numerator    2097 non-null   float64
#  6   rating_denominator  2097 non-null   object
#  7   name                1390 non-null   object
#  8   stage               336 non-null    object
#  9   retweet count       2097 non-null   int64
#  10  favorite count      2097 non-null   int64
# dtypes: datetime64[ns, UTC](1), float64(1), int64(3), object(6)
# memory usage: 196.6+ KB

# %%
merged_1
# Out:
#                 tweet_id                 timestamp  \
# 0     892420643555336193 2017-08-01 16:23:56+00:00
# 1     892177421306343426 2017-08-01 00:17:27+00:00
# 2     891815181378084864 2017-07-31 00:18:03+00:00
# 3     891689557279858688 2017-07-30 15:58:51+00:00
# 4     891327558926688256 2017-07-29 16:00:24+00:00
# ...                  ...                       ...
# 2092  666049248165822465 2015-11-16 00:24:50+00:00
# 2093  666044226329800704 2015-11-16 00:04:52+00:00
# 2094  666033412701032449 2015-11-15 23:21:54+00:00
# 2095  666029285002620928 2015-11-15 23:05:30+00:00
# 2096  666020888022790149 2015-11-15 22:32:08+00:00
#
#                                                                                   source  \
# 0     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
weRatedogs_clean[weRatedogs_clean.tweet_id == 891689557279858688]
# Out:
#              tweet_id                 timestamp  \
# 2  891689557279858688 2017-07-30 15:58:51+00:00
#
#                                                                                source  \
# 2  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                       text  \
# 2  This is Darla. She commenced a snooze mid meal. 13/10 happens to the best of us https://t.co/tD36da7qLQ
#
#                                                      expanded_urls  \
# 2  https://twitter.com/dog_rates/status/891689557279858688/photo/1
#
#    rating_numerator rating_denominator   name stage  retweet count  \
# 2  13.0              10                 Darla  NaN   8964
#
#    favorite count                                        image_url  \
# 2  42908           https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
#
#                 breed
# 2  Labrador_retriever

# %%
weRatedogs_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1666 entries, 0 to 1665
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            1666 non-null   int64
#  1   timestamp           1666 non-null   datetime64[ns, UTC]
#  2   source              1666 non-null   object
#  3   text                1666 non-null   object
#  4   expanded_urls       1666 non-null   object
#  5   rating_numerator    1666 non-null   float64
#  6   rating_denominator  1666 non-null   object
#  7   name                1186 non-null   object
#  8   stage               257 non-null    object
#  9   retweet count       1666 non-null   int64
#  10  favorite count      1666 non-null   int64
#  11  image_url           1666 non-null   object
#  12  breed               1666 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(3), object(8)
# memory usage: 182.2+ KB

# %%
sum(weRatedogs_clean['tweet_id'].duplicated())
# Out:
# 0

# %%
weRatedogs_clean
# Out:
#                 tweet_id                 timestamp  \
# 0     892177421306343426 2017-08-01 00:17:27+00:00
# 1     891815181378084864 2017-07-31 00:18:03+00:00
# 2     891689557279858688 2017-07-30 15:58:51+00:00
# 3     891327558926688256 2017-07-29 16:00:24+00:00
# 4     891087950875897856 2017-07-29 00:08:17+00:00
# ...                  ...                       ...
# 1661  666049248165822465 2015-11-16 00:24:50+00:00
# 1662  666044226329800704 2015-11-16 00:04:52+00:00
# 1663  666033412701032449 2015-11-15 23:21:54+00:00
# 1664  666029285002620928 2015-11-15 23:05:30+00:00
# 1665  666020888022790149 2015-11-15 22:32:08+00:00
#
#                                                                                   source  \
# 0     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# 1     <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %%
print(weRatedogs_clean[weRatedogs_clean.tweet_id ==822872901745569793]["text"])
# Out:
# 275    Here's a super supportive puppo participating in the Toronto  #WomensMarch today. 13/10 https://t.co/nTz3FtorBc
# Name: text, dtype: object

# %% [markdown]
# ## Storing Data
# Save gathered, assessed, and cleaned master dataset to a CSV file named "twitter_archive_master.csv".

# %%
#saving the cleaned data to a csv file
weRatedogs_clean.to_csv('twitter_archive_master.csv', index=False)

# %% [markdown]
# ## Analyzing and Visualizing Data
# In this section, analyze and visualize your wrangled data. You must produce at least **three (3) insights and one (1) visualization.**

# %%
twitter_archive_master = pd.read_csv('twitter_archive_master.csv')

# %%
twitter_archive_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1666 entries, 0 to 1665
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   tweet_id            1666 non-null   int64
#  1   timestamp           1666 non-null   object
#  2   source              1666 non-null   object
#  3   text                1666 non-null   object
#  4   expanded_urls       1666 non-null   object
#  5   rating_numerator    1666 non-null   float64
#  6   rating_denominator  1666 non-null   int64
#  7   name                1186 non-null   object
#  8   stage               257 non-null    object
#  9   retweet count       1666 non-null   int64
#  10  favorite count      1666 non-null   int64
#  11  image_url           1666 non-null   object
#  12  breed               1666 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 169.3+ KB

# %%
twitter_archive_master.breed.value_counts()
# Out:
# golden_retriever      156
# Labrador_retriever    106
# Pembroke              94
# Chihuahua             90
# pug                   62
#                       ..
# EntleBucher           1
# Japanese_spaniel      1
# standard_schnauzer    1
# silky_terrier         1
# Irish_wolfhound       1
# Name: breed, Length: 113, dtype: int64

# %% [markdown]
# ### Most retweed tweet

# %%
#getting the tweet with the most = retweets
most_retweeted = twitter_archive_master['retweet count'].idxmax()

print(twitter_archive_master["tweet_id"][most_retweeted])
# Out:
# 744234799360020481

# %%
twitter_archive_master[twitter_archive_master.tweet_id ==744234799360020481]
# Out:
#                tweet_id                  timestamp  \
# 686  744234799360020481  2016-06-18 18:26:18+00:00
#
#                                                                                  source  \
# 686  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                                     text  \
# 686  Here's a doggo realizing you can stand in a pool. 13/10 enlightened af (vid by Tina Conrad) https://t.co/7wE9LTEXC4
#
#                                                        expanded_urls  \
# 686  https://twitter.com/dog_rates/status/744234799360020481/video/1
#
#      rating_numerator  rating_denominator name  stage  retweet count  \
# 686  13.0              10                  NaN  doggo  79515
#
#      favorite count  \
# 686  131075
#
#                                                                                    image_url  \
# ...

# %% [markdown]
# ###  Most Liked Tweet

# %%
#getting the tweet id with the most likes this was done 
most_liked = twitter_archive_master['favorite count'].idxmax()
print(twitter_archive_master["tweet_id"][most_liked])
# Out:
# 822872901745569793

# %%
twitter_archive_master[twitter_archive_master.tweet_id ==822872901745569793]
# Out:
#                tweet_id                  timestamp  \
# 275  822872901745569793  2017-01-21 18:26:02+00:00
#
#                                                                                  source  \
# 275  <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
#
#                                                                                                                 text  \
# 275  Here's a super supportive puppo participating in the Toronto  #WomensMarch today. 13/10 https://t.co/nTz3FtorBc
#
#                                                        expanded_urls  \
# 275  https://twitter.com/dog_rates/status/822872901745569793/photo/1
#
#      rating_numerator  rating_denominator name  stage  retweet count  \
# 275  13.0              10                  NaN  puppo  48265
#
#      favorite count                                        image_url  \
# 275  132810          https://pbs.twimg.com/media/C2tugXLXgAArJO4.jpg
#
#                 breed
# ...

# %% [markdown]
# ### Insights:
# 1. From the wrangled data set we can conclude that the most common dog breed is a Golden retriever follwed closely by the Labrador retriever and then the Pembroke.
#
# 2. The most retweetd tweet was of a Labrador retriever with 79515 retweets but unfortunately because or faults in the data capturing or gathering process we do not know the name or have an image of this dog.
#
# 3. The most liked dog was a Lakeland retriever with 132810 likes, whose name is not known due to a data captruing error

# %% [markdown]
# ### Visualization

# %% [markdown]
# #### Which breeds  received the lowest average ratings

# %%
i = twitter_archive_master['rating_numerator'].min()
print(twitter_archive_master["breed"][i])
# Out:
# Chihuahua

# %%
naughty = twitter_archive_master.groupby('breed').mean()
naughty
# Out:
# C:\Users\bless\AppData\Local\Temp\ipykernel_18704\2044231678.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   naughty = twitter_archive_master.groupby('breed').mean()
#                                     tweet_id  rating_numerator  \
# breed
# Afghan_hound                    8.041621e+17  9.666667
# Airedale                        7.184489e+17  9.833333
# American_Staffordshire_terrier  7.597284e+17  10.312500
# Appenzeller                     7.939334e+17  11.000000
# Australian_terrier              7.785921e+17  11.500000
# ...                                      ...        ...
# toy_poodle                      7.216408e+17  11.000000
# toy_terrier                     7.166375e+17  10.333333
# vizsla                          7.474321e+17  10.846154
# ...

# %%
#ceating a dataframe with only breed and avergae rating numerator
naughty = pd.DataFrame(twitter_archive_master.groupby('breed').mean())
naughty
# Out:
# C:\Users\bless\AppData\Local\Temp\ipykernel_18704\3671247238.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   naughty = pd.DataFrame(twitter_archive_master.groupby('breed').mean())
#                                     tweet_id  rating_numerator  \
# breed
# Afghan_hound                    8.041621e+17  9.666667
# Airedale                        7.184489e+17  9.833333
# American_Staffordshire_terrier  7.597284e+17  10.312500
# Appenzeller                     7.939334e+17  11.000000
# Australian_terrier              7.785921e+17  11.500000
# ...                                      ...        ...
# toy_poodle                      7.216408e+17  11.000000
# toy_terrier                     7.166375e+17  10.333333
# vizsla                          7.474321e+17  10.846154
# ...

# %% [markdown]
# ###  visualising the breeds with the highest and lowest average ratings ratings

# %%
#bar graph to illustrate the differances
naughty.plot.barh( y="rating_numerator", ylabel="Average rating", title = "Lowest rated breeds",color='g', figsize=(16, 20));

# %%
# getting the rows of the dogs with an average rating of less than 10
bad_dog = naughty.query("rating_numerator < 10")
bad_dog
# Out:
#                             tweet_id  rating_numerator  rating_denominator  \
# breed
# Afghan_hound            8.041621e+17  9.666667          10.000000
# Airedale                7.184489e+17  9.833333          10.000000
# Boston_bull             7.286202e+17  9.416667          10.000000
# Dandie_Dinmont          7.195659e+17  9.571429          10.000000
# English_setter          7.094418e+17  9.875000          10.000000
# Ibizan_hound            6.844888e+17  9.250000          10.000000
# Japanese_spaniel        6.773010e+17  5.000000          10.000000
# Maltese_dog             6.870934e+17  9.315789          9.578947
# Mexican_hairless        7.549669e+17  9.857143          10.000000
# Newfoundland            7.379799e+17  9.857143          10.000000
# Norwich_terrier         7.429955e+17  9.600000          10.000000
# Rhodesian_ridgeback     7.218394e+17  9.750000          10.000000
# Saint_Bernard           7.101608e+17  9.857143          10.000000
# ...

# %%
#plotting the graph of  dogs with an average rating of less than 10
bad_dog["rating_numerator"].plot(kind= "bar", ylabel="Average rating",  title = "Lowest rated breeds",color='m', figsize=(16, 8), legend = True);
